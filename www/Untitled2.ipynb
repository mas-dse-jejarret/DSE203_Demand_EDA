# %%
import pandas as pd
from data_exploration2 import Sales_Reviews

# %%
r=Sales_Reviews("Education",3)

# %%
import simplejson
pd.DataFrame(simplejson.loads(r))
# Out:
#     Sentiment_polarity        asin       billdate  index       nodeid  \
# 0             0.195136  0005126207  1298937600000      0   7009083011
# 1             0.195136  0005126207  1299024000000      1   7009083011
# 2             0.195136  0005126207  1299110400000      2   7009083011
# 3             0.195136  0005126207  1299196800000      3   7009083011
# 4             0.195136  0005126207  1299456000000      4   7009083011
# 5             0.195136  0005126207  1299628800000      5   7009083011
# 6             0.195136  0005126207  1299801600000      6   7009083011
# 7             0.195136  0005126207  1300147200000      7   7009083011
# 8             0.195136  0005126207  1300233600000      8   7009083011
# 9             0.195136  0005126207  1300752000000      9   7009083011
# 10            0.195136  0005126207  1300838400000     10   7009083011
# 11            0.195136  0005126207  1301356800000     11   7009083011
# ...
