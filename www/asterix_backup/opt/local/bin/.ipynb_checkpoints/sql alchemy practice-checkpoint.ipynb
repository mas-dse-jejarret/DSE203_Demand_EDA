# %%
from sqlalchemy import Column,ForeignKey, Integer, String

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship
from sqlalchemy import create_engine

# %%
engine= create_engine('postgresql+psycopg2://postgres:Lamrin07!@localhost/Boat')

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/Boat)

# %%
from sqlalchemy.orm import sessionmaker

# %%
Base = declarative_base()
class Person (Base):
    __tablename__= 'person'
    person_id=Column(Integer, primary_key=True)
    name=Column(String(50), nullable= True)

class Contact (Base):
    __tablename__='contacts'
    contact_id=Column(Integer,primary_key=True)
    phone_number=Column(String(50),nullable=False)
    Address=Column(String(50),nullable=True)
    City=Column(String(50), nullable=True)
    Zipcode=Column(Integer, nullable=True)
    person_id=Column(Integer,ForeignKey("person.person_id"))
    person= relationship(Person)

Base.metadata.bind= engine
DBSession= sessionmaker(bind=engine)
session=DBSession()

# %%
Base.metadata.create_all(engine)

# %%
new_person=Person(name= "Nirmal Budhathoki")

session.add(new_person)
session.commit()

# %%
nc=Contact(phone_number="233",Address="address")
toby=Person(name= "Toby Moreno")

nc.person = toby

# %%
session.add(nc)
session.commit()

# %%
first=session.query(Person).first()

# %%
first.name
# Out:
# 'Nirmal Budhathoki'

# %%
for x in session.query(Person.name,Contact.phone_number)
    print (x)
# Out:
# ('Nirmal Budhathoki', '233')
# ('Toby Moreno', '233')

# %%
for x in session.query(Contact).all():
    print(x.phone_number, x.person.name)
# Out:
# 233 Toby Moreno

# %%
for x in session.query(Person,Contact).filter(Person.name == 'Toby Moreno').all():
    print(x[0].name)
# Out:
# Toby Moreno

# %%
import json
import pandas as pd
path="/Users/nirmal/Documents/DSE/nbudhath/DSE203/2017FA-DSE203/Data/reviews.json"

# %%
data = pd.read_json(path)

# %%
data.tail()
# Out:
#             asin helpful  overall  \
# 9995  0002242052  [0, 0]        5
# 9996  0002242052  [1, 1]        5
# 9997  0002242052  [0, 0]        4
# 9998  0002242052  [0, 0]        4
# 9999  0002242052  [0, 1]        5
#
#                                              reviewText   reviewTime  \
# 9995  This is probably my favorite Clancy novel to d...  12 11, 2012
# 9996  Tied with "Red Storm Rising" for my absolute f...  02 21, 2005
# 9997  I am a bit Clancy fan and have read all of his...   02 8, 2013
# 9998  to me the only things i didn't like were it se...  06 21, 2014
# 9999  A very good read. This book was a very good ve...   06 3, 2000
#
#           reviewerID          reviewerName                summary  \
# 9995   AWWK4ZVFQPC82             Mdjames05           My favorite!
# 9996  A2FHD3ZCCIAJXE  Megabyte800 "Andrew"  The cream of the crop
# 9997  A2I5TMZEVW09B5               Melissa         Classic Clancy
# 9998  A196S58LYV9FGG          melvin cohen                  long?
# ...

# %%
data['reviewText'].describe()
# Out:
# count     77164
# unique    77137
# top
# freq          9
# Name: reviewText, dtype: object

# %%
a
# Out:
#                                       asin  helpful  overall  reviewText  \
# reviewerName
#  Kasper "Miso Kitten"                    1        1        1           1
# !@#$%L.L. "Max"                          1        1        1           1
# "-addy-"                                 1        1        1           1
# "-dragon-girl-"                          1        1        1           1
# "1bigfig"                                1        1        1           1
# "75mark"                                 1        1        1           1
# "Bobby Wickham"                          1        1        1           1
# "KB" Kamla Srinivasan                    3        3        3           3
# "Reader of Suspense" "Ali"               1        1        1           1
# "Weighting" no more!                     1        1        1           1
# "_babygurl"                              1        1        1           1
# "_king_peace"                            1        1        1           1
# ...
