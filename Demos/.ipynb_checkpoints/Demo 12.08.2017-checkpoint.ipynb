# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
print (sys.path)
sys.path.append('../www')
# Out:
# ['', '/Users/toby/s/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip', '/Users/toby/s/spark-2.1.0-bin-hadoop2.7/python', '/Users/toby/PycharmProjects/DSE203_Demand_EDA/Demos', '/Users/toby/.conda/envs/py3/lib/python36.zip', '/Users/toby/.conda/envs/py3/lib/python3.6', '/Users/toby/.conda/envs/py3/lib/python3.6/lib-dynload', '/Users/toby/.conda/envs/py3/lib/python3.6/site-packages', '/Users/toby/.conda/envs/py3/lib/python3.6/site-packages/Sphinx-1.5.6-py3.6.egg', '/Users/toby/.conda/envs/py3/lib/python3.6/site-packages/aeosa', '/Users/toby/.conda/envs/py3/lib/python3.6/site-packages/setuptools-27.2.0-py3.6.egg', '/Users/toby/.conda/envs/py3/lib/python3.6/site-packages/IPython/extensions', '/Users/toby/.ipython', '../www']

# %%
from data_exploration2 import *

# %%
import requests
import pandas as pd
import ast
import matplotlib as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['text', 'table', 'loads', 'plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Current API Methods
#
# ## 1. Correlation coefficient between 2 columns in a table.

# %%
# regular api

# %%
col1 = 'numunits'
col2 = 'productid'
table1 = 'orderlines'
table2 = 'products'
key1 = 'productid'
key2 = 'productid'

col_pair = (col1,col2)
table_pair = (table1,table2)
key_pair = (key1,key2)

response=Correlation(col_pair, table_pair, key_pair)

print(response)
# Out:
# {"correlation": 0.00643616130791823}

# %% [markdown]
# ## 2. Covariance coefficient between 2 columns in a table.

# %%
col1 = 'numunits'
col2 = 'productid'
table1 = 'orderlines'
table2 = 'products'
key1 = 'productid'
key2 = 'productid'

col_pair = (col1,col2)
table_pair = (table1,table2)
key_pair = (key1,key2)

response=Covariance(col_pair, table_pair, key_pair)

print(response)
# Out:
# {"covariance": 93.5788384664056}

# %% [markdown]
# ## 3. Simple Histogram

# %%
table = "orders"
groupby = 'state'
count = 'customerid'
response = Histogram(table, groupby, count)
data = ast.literal_eval(response)
df = pd.DataFrame(data)
x = np.array(range(len(df['Group'])))
y = np.array(df['Count'])
my_xticks = list(df['Group'])
plt.figure(figsize=[30,15])
plt.xticks(x, my_xticks, fontsize=14, rotation='vertical')
plt.bar(x, y)
plt.title('Customer count by state', fontsize=20)
plt.xlabel('State', fontsize=16)
plt.ylabel('Customer id count', fontsize=16);

# %% [markdown]
# ## 4. What are the top categories of books read in a particular month(s)?
#     Sample Query: What are the top 3 categories of books that are most read around Christmas?
#
#     @app.route("/api/Top_Categories/<num_categories>/<month>")

# %%
num_categories = 5
months = [12]
tc = OptimizedTopCategories(num_categories, months)
print(tc)
# Out:
# [('Education & Reference', 9689.0), ('Graphics & Design', 4070.0), ('Geography & Cultures', 3763.0), ('Programming', 3699.0), ('Science, Nature & How It Works', 2997.0)]

# %% [markdown]
# ## 5. Generalized Query: What time of the year are the sales of  X category/ies of book the highest?
#     Sample Query: What time of the year are the sales of “Education” books the highest?

# %%
list='Education & Reference'
category_list = list.split(",")

print("\nHighest Monthly Sales By Category: \n")

#hmsb = HighestMonthlySalesByCategory('Education & Reference')
limit = 5
hmsb = HighestMonthlySalesByCategory(category_list, 5)
print(hmsb)
# Out:
# Highest Monthly Sales By Category:
#
# [{'mon': 12, 'num_sold': 9689}, {'mon': 11, 'num_sold': 7096}, {'mon': 5, 'num_sold': 4028}, {'mon': 6, 'num_sold': 3715}, {'mon': 1, 'num_sold': 3659}]

# %% [markdown]
# ## 6. Sentiment polarity score for all reviews extracted for Solr datasource
#     @app.route('/sentiment_polarity/<category>/<month>', methods=['GET'])

# %%
print("Sentiment Polarity: \n")
sr = Sales_Reviews("Education", 3)
print (sr)
# Out:
# Sentiment Polarity:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'asin_str'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-97af349a9c74> in <module>()
#       1 print("Sentiment Polarity: \n")
# ----> 2 sr = Sales_Reviews("Education", 3)
#       3 print (sr)
#
# /Users/toby/PycharmProjects/DSE203_Demand_EDA/www/data_exploration2.py in Sales_Reviews(category, month)
#     531     se = pd.Series(polarity_measure)
#     532     d_res3['Sentiment_polarity'] = se.values
# --> 533     d_res3['asin'] = d_res3['asin_str'].apply(lambda x: '' + str(x)[2:-2] + '')
#     534     df_sentiment = d_res3.groupby(['asin'], as_index=False)['Sentiment_polarity'].mean()
#     535     result = pd.merge(df3, df_sentiment, on='asin', how='inner')
#
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/toby/.conda/envs/py3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'asin_str'

# %% [markdown]
# ## 7. Which book categories show a downward trend in demand in a particular month?
#     Sample Query: Which book categories show a downward trend in demand in Winter and Spring?
#
#     @app.route("/api/Downward_Sales/<season>")

# %%
season = 'spring'
url = 'http://localhost/api/Downward_Sales/'+season
response = requests.get(url)
j = response.json()
df = pd.DataFrame(j)
df.set_index('category', inplace=True)
df.head()
# Out:
#             SaleTrend
# category
# 2963             -364
# 8944264011       -257
# 8951153011       -153
# 8944258011       -130
# 1007             -116

# %% [markdown]
# ## 8. Is there a category which performs poorly in a date range?
#     Sample Query: Is there a category that we should discontinue stocking?
#
#     @app.route("/api/Discontinue_Stocking/<threshold>/<startyear>/<endyear>")

# %%
threshold = '5'
startyear = '2013'
endyear = '2014'
url = 'http://localhost/api/Discontinue_Stocking/'+threshold+'/'+startyear+'/'+endyear
response = requests.get(url)
response.text
# Out:
# '[{"category": "10020677011"}, {"category": "10020679011"}, {"category": "10020695011"}, {"category": "10020696011"}, {"category": "10020700011"}, {"category": "10020701011"}, {"category": "10020702011"}, {"category": "10020703011"}, {"category": "10020704011"}, {"category": "10020709011"}, {"category": "10020710011"}, {"category": "10020711011"}, {"category": "10020716011"}, {"category": "10020718011"}, {"category": "10020722011"}, {"category": "10020723011"}, {"category": "1005"}, {"category": "10056624011"}, {"category": "10056625011"}, {"category": "10056628011"}, {"category": "10056630011"}, {"category": "10056633011"}, {"category": "10056634011"}, {"category": "10056635011"}, {"category": "10056636011"}, {"category": "10056638011"}, {"category": "10056639011"}, {"category": "10056640011"}, {"category": "10056642011"}, {"category": "10056644011"}, {"category": "10094987011"}, {"category": "10099177011"}, {"category": "10099184011"}, {"category": "10099192011"}, {"category": "10166931011"}, {"category": "1019"}, {"category": "10368615011"}, {"category": "1043842"}, {"category": "1043856"}, {"category": "1043858"}, {"category": "1043966"}, {"category
# Philosophy
# Photography & Video
# Poetry
# Pregnancy & Childbirth
# Programming
# Protestantism
# Quick & Easy
# Racket Sports
# Reference
# Regional & International
# Regional U.S.
# Renaissance
# Rodeos
# Romance
# Romance Manga
# Romantic Comedy
# Romantic Suspense
# Rules & Procedures
# Schools & Teaching
# Science Fiction & Fantasy
# Science for Kids
# Science, Nature & How It Works
# Security & Encryption
# Self-Esteem
# Sex
# Sexual Health
# Skills
# Social Sciences
# Sociology
# Software
# South America
# Special Diet
# Sports
# Study & Teaching
# Success
# Sustainable Living
# TOEFL & TOEIC
# Teen Health
# Television
# Test Preparation
# Theology
# Time Travel
# Training
# Travel Writing
# True Crime
# U.S. Cooking
# United States
# Vampires
# Vehicle Pictorials
# Veterinary Medicine
# Web Development & Design
# Weddings
# Werewolves & Shifters
# Western
# Women's Fiction
# Women's Health
# Women's Studies
# World
# World Literature
# Writing
# Writing, Research & Publishing Guides

# %%
ct
# Out:
# [('Education & Reference', 47025.0),
#  ('Geography & Cultures', 21831.0),
#  ('Programming', 19663.0),
#  ('Science, Nature & How It Works', 18123.0),
#  ('Graphics & Design', 15957.0),
#  ('Animals', 14129.0),
#  ('Early Learning', 14008.0),
#  ('Engineering', 13739.0),
#  ('Home Improvement & Design', 13503.0),
#  ('Growing Up & Facts of Life', 12337.0),
#  ('History', 12179.0),
#  ('Architecture', 10012.0)]

# %%
getOptimizedCategories()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-7b9b9b699f07> in <module>()
# ----> 1 getOptimizedCategories()
#
# NameError: name 'getOptimizedCategories' is not defined

# %%
[x[0] for x in tc[:50]]
# Out:
# ['Education & Reference',
#  'Geography & Cultures',
#  'Programming',
#  'Science, Nature & How It Works',
#  'Graphics & Design',
#  'Animals',
#  'Early Learning',
#  'Engineering',
#  'Home Improvement & Design',
#  'Growing Up & Facts of Life',
#  'History',
#  'Architecture',
#  'Regional & International',
#  'Programming Languages',
#  'Cars, Trains & Things That Go',
#  "Women's Health",
#  'Digital Audio, Video & Photography',
#  'Software',
#  'Transportation',
#  'Automotive',
#  'Hardware & DIY',
#  'Music',
#  'Pregnancy & Childbirth',
#  'Photography & Video',
#  'Military',
#  'Crafts & Hobbies',
#  'Christian Books & Bibles',
#  'Comics & Graphic Novels',
#  'Games & Strategy Guides',
#  'Biographies',
#  'Asian Cooking',
#  'Needlecrafts & Textile Crafts',
#  'Aging',
#  'Investing',
#  'Activities, Crafts & Games',
#  'Fairy Tales, Folk Tales & Myths',
#  'Physics',
#  'Gardening & Landscape Design',
#  'Web Development & Design',
#  'Literature & Fiction',
#  'Nature & Ecology',
#  'Mental Health',
#  'Religions',
#  'Puzzles & Games',
#  'Diseases & Physical Ailments',
#  'Europe',
#  "Children's & Teens",
#  'Industries',
#  'Africa',
#  'Management & Leadership']

# %%
getNodeIds(["Women's Fiction"])
# Out:
# [{'nodeID': 542654},
#  {'nodeID': 9059881011},
#  {'nodeID': 3559170011},
#  {'nodeID': 542660},
#  {'nodeID': 542656},
#  {'nodeID': 542662},
#  {'nodeID': 542658},
#  {'nodeID': 542666},
#  {'nodeID': 542664}]

# %%
sorted(tc.values())
# Out:
# [0, 1.0, 6.0]

# %%
cats = getCategories()

# %%
getTopCategories()
# Out:
# ['Education & Reference',
#  'Geography & Cultures',
#  'Programming',
#  'Science, Nature & How It Works',
#  'Graphics & Design',
#  'Animals',
#  'Early Learning',
#  'Engineering',
#  'Home Improvement & Design',
#  'Growing Up & Facts of Life',
#  'History',
#  'Architecture',
#  'Regional & International',
#  'Programming Languages',
#  'Cars, Trains & Things That Go',
#  "Women's Health",
#  'Digital Audio, Video & Photography',
#  'Software',
#  'Transportation',
#  'Automotive',
#  'Hardware & DIY',
#  'Music',
#  'Pregnancy & Childbirth',
#  'Photography & Video',
#  'Military',
#  'Crafts & Hobbies',
#  'Christian Books & Bibles',
#  'Comics & Graphic Novels',
#  'Games & Strategy Guides',
#  'Biographies',
#  'Asian Cooking',
#  'Needlecrafts & Textile Crafts',
#  'Aging',
#  'Investing',
#  'Activities, Crafts & Games',
#  'Fairy Tales, Folk Tales & Myths',
#  'Physics',
#  'Gardening & Landscape Design',
#  'Web Development & Design',
#  'Literature & Fiction',
#  'Nature & Ecology',
#  'Mental Health',
#  'Religions',
#  'Puzzles & Games',
#  'Diseases & Physical Ailments',
#  'Europe',
#  "Children's & Teens",
#  'Industries',
#  'Africa',
#  'Management & Leadership']

# %%
OptimizedTopCategories(3, [5])
# Out:
# [('Education & Reference', 4028.0),
#  ('Science, Nature & How It Works', 1985.0),
#  ('Programming', 1604.0)]

# %%
getCategories()
# Out:
# [{'category': 'Abuse'},
#  {'category': 'Action & Adventure'},
#  {'category': 'Action & Adventure Manga'},
#  {'category': 'Adoption'},
#  {'category': 'Africa'},
#  {'category': 'Aging'},
#  {'category': 'Aging Parents'},
#  {'category': 'Allied Health Professions'},
#  {'category': 'Alternative Medicine'},
#  {'category': 'Americas'},
#  {'category': 'Animals'},
#  {'category': 'Anthologies'},
#  {'category': 'Anxieties & Phobias'},
#  {'category': 'Archaeology'},
#  {'category': 'Architecture'},
#  {'category': 'Arctic & Antarctica'},
#  {'category': 'Art of Comics and Manga'},
#  {'category': 'Atheism'},
#  {'category': 'Australia & Oceania'},
#  {'category': 'Australia & South Pacific'},
#  {'category': 'Automotive'},
#  {'category': 'Babysitting, Day Care & Child Care'},
#  {'category': 'Baking'},
#  {'category': 'Baseball'},
#  {'category': 'Beauty, Grooming, & Style'},
#  {'category': 'Behavioral Sciences'},
#  {'category': 'Bible Study & Reference'},
#  {'category': 'Biography & History'},
#  {'category': 'Buddhism'},
#  {'category': 'Business'},
#  {'category': 'Careers'},
#  {'category': 'Caribbean'},
#  {'category': 'Cars, Trains & Things That Go'},
#  {'category': 'Catalogs & Directories'},
#  {'category': 'Catholicism'},
#  {'category': 'Chemistry'},
#  {'category': "Children's & Teens"},
#  {'category': 'Christian Books & Bibles'},
#  {'category': 'Christian Denominations & Sects'},
#  {'category': 'Coaching'},
#  {'category': 'Collections, Catalogs & Exhibitions'},
#  {'category': 'Coloring Books for Grown-Ups'},
#  {'category': 'Computers & Technology'},
#  {'category': 'Contemporary'},
#  {'category': 'Cooking Methods'},
#  {'category': 'Crafts & Hobbies'},
#  {'category': 'Crime'},
#  {'category': 'Criminal Law'},
#  {'category': 'Death & Grief'},
#  {'category': 'Dentistry'},
#  {'category': 'Desserts'},
#  {'category': 'Dictionaries & Terminology'},
#  {'category': 'Dictionaries & Thesauruses'},
#  {'category': 'Dramas & Plays'},
#  {'category': 'Eating Disorders'},
#  {'category': 'Economics'},
#  {'category': 'Education & Reference'},
#  {'category': 'Emotions'},
#  {'category': 'Engineering'},
#  {'category': 'Essays & Commentary'},
#  {'category': 'Essays & Correspondence'},
#  {'category': 'Ethnic & National'},
#  {'category': 'Etiquette'},
#  {'category': 'Evolution'},
#  {'category': 'Exercise & Fitness'},
#  {'category': 'Fairy Tales, Folk Tales & Myths'},
#  {'category': 'Family Activities'},
#  {'category': 'Family Health'},
#  {'category': 'Family Law'},
#  {'category': 'Fantasy'},
#  {'category': 'Fashion'},
#  {'category': 'Fertility'},
#  {'category': 'Field Guides'},
#  {'category': 'Football (American)'},
#  {'category': 'Foreign & International Law'},
#  {'category': 'Foreign Language Fiction'},
#  {'category': 'Foreign Language Study & Reference'},
#  {'category': 'Games & Strategy Guides'},
#  {'category': 'Gaming'},
#  {'category': 'Gay Romance'},
#  {'category': 'General'},
#  {'category': 'Genre Fiction'},
#  {'category': 'Graphics & Design'},
#  {'category': 'Growing Up & Facts of Life'},
#  {'category': 'Hardware & DIY'},
#  {'category': 'Hiking & Camping'},
#  {'category': 'Historical'},
#  {'category': 'Historical Fiction'},
#  {'category': 'History'},
#  {'category': 'History & Culture'},
#  {'category': 'History & Philosophy'},
#  {'category': 'Holidays & Celebrations'},
#  {'category': 'Human Resources'},
#  {'category': 'Hunting & Fishing'},
#  {'category': 'Individual Sports'},
#  {'category': 'Insurance'},
#  {'category': 'International'},
#  {'category': 'Investing'},
#  {'category': 'Italian Cooking'},
#  {'category': 'Job Hunting & Careers'},
#  {'category': 'Judaism'},
#  {'category': 'Kitchen Appliances'},
#  {'category': 'Leaders & Notable People'},
#  {'category': 'Legal Education'},
#  {'category': 'Legal Self-Help'},
#  {'category': 'Legal Theory & Systems'},
#  {'category': 'Literature & Fiction'},
#  {'category': 'Manga'},
#  {'category': 'Marketing & Sales'},
#  {'category': 'Mathematics'},
#  {'category': 'Media Tie-In Graphic Novels'},
#  {'category': 'Medical Informatics'},
#  {'category': 'Mental Health'},
#  {'category': 'Mexico'},
#  {'category': 'Ministry & Evangelism'},
#  {'category': 'Miscellaneous'},
#  {'category': 'Motivational'},
#  {'category': 'Mysteries & Detectives'},
#  {'category': 'Nature & Ecology'},
#  {'category': 'Nature Travel'},
#  {'category': 'Neuro-Linguistic Programming'},
#  {'category': 'New Age'},
#  {'category': 'New Age & Spirituality'},
#  {'category': 'Occult & Paranormal'},
#  {'category': 'Other Eastern Religions & Sacred Texts'},
#  {'category': 'Other Media'},
#  {'category': 'Other Religions, Practices & Sacred Texts'},
#  {'category': 'Other Team Sports'},
#  {'category': 'Outdoor Cooking'},
#  {'category': 'Outdoor Recreation'},
#  {'category': 'Parenting'},
#  {'category': 'Parenting & Families'},
#  {'category': 'Performing Arts'},
#  {'category': 'Personal Finance'},
#  {'category': 'Pets & Animal Care'},
#  {'category': 'Physics'},
#  {'category': 'Pictorial'},
#  {'category': 'Polar Regions'},
#  {'category': 'Politics & Government'},
#  {'category': 'Pop Culture'},
#  {'category': 'Processes & Infrastructure'},
#  {'category': 'Professional'},
#  {'category': 'Professional Cooking'},
#  {'category': 'Professionals & Academics'},
#  {'category': 'Programming Languages'},
#  {'category': 'Psychology'},
#  {'category': 'Psychology & Counseling'},
#  {'category': 'Puzzles & Games'},
#  {'category': 'Quotations'},
#  {'category': 'Radio'},
#  {'category': 'Real Estate'},
#  {'category': 'Reference & Collections'},
#  {'category': 'Regency'},
#  {'category': 'Regional Canada'},
#  {'category': 'Relationships'},
#  {'category': 'Religion & Spirituality'},
#  {'category': 'Religions'},
#  {'category': 'Religious'},
#  {'category': 'Religious Art'},
#  {'category': 'Religious Studies'},
#  {'category': 'Research'},
#  {'category': 'Russia'},
#  {'category': 'Safety & First Aid'},
#  {'category': 'Science Fiction'},
#  {'category': 'Science Fiction Graphic Novels'},
#  {'category': 'Sculpture'},
#  {'category': 'Short Stories & Anthologies'},
#  {'category': 'Small Business & Entrepreneurship'},
#  {'category': 'Soccer'},
#  {'category': 'Social Issues'},
#  {'category': 'Softball'},
#  {'category': 'Special Needs'},
#  {'category': 'Specialties'},
#  {'category': 'Specialty Travel'},
#  {'category': 'Specific Groups'},
#  {'category': 'Spiritual'},
#  {'category': 'Sports & Outdoors'},
#  {'category': 'Sports Health & Safety'},
#  {'category': 'Stress Management'},
#  {'category': 'Study Guides & Workbooks'},
#  {'category': 'Studying & Workbooks'},
#  {'category': 'Superheroes'},
#  {'category': 'Survival & Emergency Preparedness'},
#  {'category': 'Survival Skills'},
#  {'category': 'Tax Law'},
#  {'category': 'Taxation'},
#  {'category': 'Technology'},
#  {'category': 'Test Flash Cards'},
#  {'category': 'Thrillers & Suspense'},
#  {'category': 'Time Management'},
#  {'category': 'Transportation'},
#  {'category': 'Travel'},
#  {'category': 'Travelers & Explorers'},
#  {'category': 'Trivia & Fun Facts'},
#  {'category': 'Vaccinations'},
#  {'category': 'Vegetarian & Vegan'},
#  {'category': 'Water Sports'},
#  {'category': 'Winter Sports'},
#  {'category': 'Women & Business'},
#  {'category': 'Words, Language & Grammar'},
#  {'category': 'Worship & Devotion'},
#  {'category': 'Accounting'},
#  {'category': 'Activities, Crafts & Games'},
#  {'category': 'Addiction & Recovery'},
#  {'category': 'Administration & Medicine Economics'},
#  {'category': 'Administrative Law'},
#  {'category': 'Adventure Travel'},
#  {'category': 'African American'},
#  {'category': 'Agnosticism'},
#  {'category': 'Agricultural Sciences'},
#  {'category': 'Almanacs & Yearbooks'},
#  {'category': 'Ancient & Medieval Literature'},
#  {'category': 'Ancient Civilizations'},
#  {'category': 'Anger Management'},
#  {'category': 'Anthropology'},
#  {'category': 'Antiques & Collectibles'},
#  {'category': 'Art Therapy & Relaxation'},
#  {'category': 'Art, Music & Photography'},
#  {'category': 'Arts & Literature'},
#  {'category': 'Arts, Music & Photography'},
#  {'category': 'Asia'},
#  {'category': 'Asian Cooking'},
#  {'category': 'Astronomy & Space Science'},
#  {'category': 'Atlases & Maps'},
#  {'category': 'Basic Sciences'},
#  {'category': 'Basketball'},
#  {'category': 'Beverages & Wine'},
#  {'category': 'Bibles'},
#  {'category': 'Biographies'},
#  {'category': 'Biographies & History Graphic Novels'},
#  {'category': 'Biographies & Memoirs'},
#  {'category': 'Biological Sciences'},
#  {'category': 'British & Irish'},
#  {'category': 'Business Culture'},
#  {'category': 'Business Technology'},
#  {'category': 'Business of Art'},
#  {'category': 'Canada'},
#  {'category': 'Canning & Preserving'},
#  {'category': 'Celebrities & TV Shows'},
#  {'category': 'Central America'},
#  {'category': 'Certification'},
#  {'category': "Children's & Youth Sports"},
#  {'category': "Children's Cookbooks"},
#  {'category': "Children's Health"},
#  {'category': 'Christian Living'},
#  {'category': 'Churches & Church Leadership'},
#  {'category': 'Citizenship'},
#  {'category': 'Classics'},
#  {'category': 'Clean & Wholesome'},
#  {'category': 'College & High School'},
#  {'category': 'Comic Strips'},
#  {'category': 'Comics & Graphic Novels'},
#  {'category': 'Communication & Social Skills'},
#  {'category': 'Computer Science'},
#  {'category': 'Constitutional Law'},
#  {'category': 'Consumer Guides'},
#  {'category': 'Cooking Education & Reference'},
#  {'category': 'Cooking by Ingredient'},
#  {'category': 'Creativity'},
#  {'category': 'Databases & Big Data'},
#  {'category': 'Decorative Arts & Design'},
#  {'category': 'Diets & Weight Loss'},
#  {'category': 'Digital Audio, Video & Photography'},
#  {'category': 'Diseases & Physical Ailments'},
#  {'category': 'Drawing'},
#  {'category': 'Dreams'},
#  {'category': "Driver's Education"},
#  {'category': 'Early Learning'},
#  {'category': 'Earth Sciences'},
#  {'category': 'Education'},
#  {'category': 'Encyclopedias & Subject Guides'},
#  {'category': 'English as a Second Language'},
#  {'category': 'Entertaining & Holidays'},
#  {'category': 'Environment'},
#  {'category': 'Environmental & Natural Resources Law'},
#  {'category': 'Erotica'},
#  {'category': 'Estate Planning'},
#  {'category': 'Ethics & Professional Responsibility'},
#  {'category': 'Europe'},
#  {'category': 'Event Planning'},
#  {'category': 'Experiments, Instruments & Measurement'},
#  {'category': 'Extreme Sports'},
#  {'category': 'Family Relationships'},
#  {'category': 'Fantasy Graphic Novels'},
#  {'category': 'Finance'},
#  {'category': 'Food, Lodging & Transportation'},
#  {'category': 'Gardening & Landscape Design'},
#  {'category': 'Genealogy'},
#  {'category': 'Geography & Cultures'},
#  {'category': 'Golf'},
#  {'category': 'Gothic'},
#  {'category': 'Graduate School'},
#  {'category': 'Graphic Design'},
#  {'category': 'Graphic Novels'},
#  {'category': 'Handwriting Analysis'},
#  {'category': 'Happiness'},
#  {'category': 'Health & Medical Law'},
#  {'category': 'Higher & Continuing Education'},
#  {'category': 'Hinduism'},
#  {'category': 'Historical Study & Educational Resources'},
#  {'category': 'History & Criticism'},
#  {'category': 'History & Price Guides'},
#  {'category': 'Hobbies & Games'},
#  {'category': 'Hockey'},
#  {'category': 'Holidays'},
#  {'category': 'Home Improvement & Design'},
#  {'category': 'How To Create Comics & Manga'},
#  {'category': 'Humor'},
#  {'category': 'Humor & Satire'},
#  {'category': 'Hypnosis'},
#  {'category': 'Individual Artists'},
#  {'category': 'Industries'},
#  {'category': 'Inner Child'},
#  {'category': 'Inspirational'},
#  {'category': 'Intellectual Property'},
#  {'category': 'Internet & Social Media'},
#  {'category': 'Islam'},
#  {'category': 'Journal Writing'},
#  {'category': 'LGBT'},
#  {'category': 'Law Practice'},
#  {'category': 'Legal History'},
#  {'category': 'Lesbian Romance'},
#  {'category': 'Literary'},
#  {'category': 'Main Courses & Side Dishes'},
#  {'category': 'Management & Leadership'},
#  {'category': 'Marriage & Adult Relationships'},
#  {'category': 'Media & the Law'},
#  {'category': 'Medicine'},
#  {'category': 'Medieval'},
#  {'category': 'Memoirs'},
#  {'category': 'Memory Improvement'},
#  {'category': "Men's Health"},
#  {'category': 'Mid-Life'},
#  {'category': 'Middle East'},
#  {'category': 'Military'},
#  {'category': 'Mobile Phones, Tablets & E-Readers'},
#  {'category': 'Modern (16th-21st Centuries)'},
#  {'category': 'Mountaineering'},
#  {'category': 'Movies'},
#  {'category': 'Multicultural'},
#  {'category': 'Music'},
#  {'category': 'Mysteries & Thrillers'},
#  {'category': 'Mystery'},
#  {'category': 'Mystery & Thrillers'},
#  {'category': 'Mythology & Folk Tales'},
#  {'category': 'N/A'},
#  {'category': 'Needlecrafts & Textile Crafts'},
#  {'category': 'Networking & Cloud Computing'},
#  {'category': 'New Adult & College'},
#  {'category': 'Nonfiction'},
#  {'category': 'Nursing'},
#  {'category': 'Nutrition'},
#  {'category': 'Operating Systems'},
#  {'category': 'Painting'},
#  {'category': 'Paranormal'},
#  {'category': 'Personal Health'},
#  {'category': 'Personal Transformation'},
#  {'category': 'Pharmacology'},
#  {'category': 'Philosophy'},
#  {'category': 'Photography & Video'},
#  {'category': 'Poetry'},
#  {'category': 'Pregnancy & Childbirth'},
#  {'category': 'Programming'},
#  {'category': 'Protestantism'},
#  {'category': 'Quick & Easy'},
#  {'category': 'Racket Sports'},
#  {'category': 'Reference'},
#  {'category': 'Regional & International'},
#  {'category': 'Regional U.S.'},
#  {'category': 'Renaissance'},
#  {'category': 'Rodeos'},
#  {'category': 'Romance'},
#  {'category': 'Romance Manga'},
#  {'category': 'Romantic Comedy'},
#  {'category': 'Romantic Suspense'},
#  {'category': 'Rules & Procedures'},
#  {'category': 'Schools & Teaching'},
#  {'category': 'Science Fiction & Fantasy'},
#  {'category': 'Science for Kids'},
#  {'category': 'Science, Nature & How It Works'},
#  {'category': 'Security & Encryption'},
#  {'category': 'Self-Esteem'},
#  {'category': 'Sex'},
#  {'category': 'Sexual Health'},
#  {'category': 'Skills'},
#  {'category': 'Social Sciences'},
#  {'category': 'Sociology'},
#  {'category': 'Software'},
#  {'category': 'South America'},
#  {'category': 'Special Diet'},
#  {'category': 'Sports'},
#  {'category': 'Study & Teaching'},
#  {'category': 'Success'},
#  {'category': 'Sustainable Living'},
#  {'category': 'TOEFL & TOEIC'},
#  {'category': 'Teen Health'},
#  {'category': 'Television'},
#  {'category': 'Test Preparation'},
#  {'category': 'Theology'},
#  {'category': 'Time Travel'},
#  {'category': 'Training'},
#  {'category': 'Travel Writing'},
#  {'category': 'True Crime'},
#  {'category': 'U.S. Cooking'},
#  {'category': 'United States'},
#  {'category': 'Vampires'},
#  {'category': 'Vehicle Pictorials'},
#  {'category': 'Veterinary Medicine'},
#  {'category': 'Web Development & Design'},
#  {'category': 'Weddings'},
#  {'category': 'Werewolves & Shifters'},
#  {'category': 'Western'},
#  {'category': "Women's Fiction"},
#  {'category': "Women's Health"},
#  {'category': "Women's Studies"},
#  {'category': 'World'},
#  {'category': 'World Literature'},
#  {'category': 'Writing'},
#  {'category': 'Writing, Research & Publishing Guides'}]

# %%
getTopCategories()
# Out:
# [{'category': 'Education & Reference'},
#  {'category': 'Geography & Cultures'},
#  {'category': 'Programming'},
#  {'category': 'Science, Nature & How It Works'},
#  {'category': 'Graphics & Design'},
#  {'category': 'Animals'},
#  {'category': 'Early Learning'},
#  {'category': 'Engineering'},
#  {'category': 'Home Improvement & Design'},
#  {'category': 'Growing Up & Facts of Life'},
#  {'category': 'History'},
#  {'category': 'Architecture'},
#  {'category': 'Regional & International'},
#  {'category': 'Programming Languages'},
#  {'category': 'Cars, Trains & Things That Go'},
#  {'category': "Women's Health"},
#  {'category': 'Digital Audio, Video & Photography'},
#  {'category': 'Software'},
#  {'category': 'Transportation'},
#  {'category': 'Automotive'},
#  {'category': 'Hardware & DIY'},
#  {'category': 'Music'},
#  {'category': 'Pregnancy & Childbirth'},
#  {'category': 'Photography & Video'},
#  {'category': 'Military'},
#  {'category': 'Crafts & Hobbies'},
#  {'category': 'Christian Books & Bibles'},
#  {'category': 'Comics & Graphic Novels'},
#  {'category': 'Games & Strategy Guides'},
#  {'category': 'Biographies'},
#  {'category': 'Asian Cooking'},
#  {'category': 'Needlecrafts & Textile Crafts'},
#  {'category': 'Aging'},
#  {'category': 'Investing'},
#  {'category': 'Activities, Crafts & Games'},
#  {'category': 'Fairy Tales, Folk Tales & Myths'},
#  {'category': 'Physics'},
#  {'category': 'Gardening & Landscape Design'},
#  {'category': 'Web Development & Design'},
#  {'category': 'Literature & Fiction'},
#  {'category': 'Nature & Ecology'},
#  {'category': 'Mental Health'},
#  {'category': 'Religions'},
#  {'category': 'Puzzles & Games'},
#  {'category': 'Diseases & Physical Ailments'},
#  {'category': 'Europe'},
#  {'category': "Children's & Teens"},
#  {'category': 'Industries'},
#  {'category': 'Africa'},
#  {'category': 'Management & Leadership'}]
